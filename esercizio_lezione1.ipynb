# %%
nome = input("Inserisci il tuo nome: ").strip()
if len(nome) == 0:
    print("Devi inserire un nome valido")
    
cognome = input("Inserisci il tuo cognome: ").strip()
if len(cognome) == 0:
   print("Devi inserire un cognome valido")
   
eta = int(input("Inserisci il tuo età: ").strip())
if eta < 0:
    print("Devi inserire un età valida")
    
#print("Nome completo: ", nome.upper(), cognome.lower())
#print("Età: ", eta)
#print("Lunghezza nome : ", len(nome))
#print("Lunghezza cognome : ", len(cognome))
#print("Tipo della variabile età: ", type(eta))

print(f"Nome completo: {nome.upper()} {cognome.lower()}")
print(f"Età: {eta}")
print(f"Lunghezza nome: {len(nome)}")
print(f"Lunghezza cognome: {len(cognome)}")
print(f"Variabile età: {type(eta)}")
# Out:
# Nome completo: LINDA ferrara
# Età: 19
# Lunghezza nome: 5
# Lunghezza cognome: 7
# Variabile età: <class 'int'>
